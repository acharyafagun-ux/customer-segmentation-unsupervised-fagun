# %% [markdown]
# # 02 - Exploratory Data Analysis (EDA)
#
# Objective:
# Explore cleaned dataset distributions and relationships before feature engineering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
df = pd.read_csv("../data/processed/cleaned_data.csv")

df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.describe()
# Out:
#            InvoiceNo       Quantity      UnitPrice     CustomerID
# count  397884.000000  397884.000000  397884.000000  397884.000000
# mean   560616.934451      12.988238       3.116488   15294.423453
# std     13106.117773     179.331775      22.097877    1713.141560
# min    536365.000000       1.000000       0.001000   12346.000000
# 25%    549234.000000       2.000000       1.250000   13969.000000
# 50%    561893.000000       6.000000       1.950000   15159.000000
# 75%    572090.000000      12.000000       3.750000   16795.000000
# max    581587.000000   80995.000000    8142.750000   18287.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Quantity"], bins=50)
plt.title("Quantity Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["UnitPrice"], bins=50)
plt.title("UnitPrice Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[["Quantity", "UnitPrice"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Observations
#
# - Dataset contains ~397k valid transactions after cleaning.
# - Quantity and UnitPrice distributions are heavily right-skewed.
# - Extreme outliers exist in Quantity and UnitPrice.
# - No strong correlation between Quantity and UnitPrice.
# - Log transformation and scaling will be required before clustering.
